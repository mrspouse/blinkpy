# %%
# pip install --upgrade pip
import json

# %%
from blinkpy.blinkpy import Blink
from blinkpy.auth import Auth
from blinkpy.helpers.util import json_load

blink = Blink()
auth = Auth(json_load("/Users/glyn/Git/blinkpy/auth.json"))
blink.auth = auth
blink.start()
# Out:
# True

# %%
    blink.auth.send_auth_key(blink, 874172)
    blink.setup_post_verify()

# %%
    from blinkpy.blinkpy import Blink
    from blinkpy.auth import Auth

    blink = Blink()
    # Can set no_prompt when initializing auth handler
    auth = Auth({"username": "drkandmrg@gmail.com", "password": "Ashfield@47"}, no_prompt=True)
    blink.auth = auth
    blink.start()

# %%
blink.save(file_name="auth.json")

# %%
Blink.get_homescreen(blink)
json_data = blink.homescreen

pretty_json = json.dumps(json_data, indent=4) 
print(pretty_json)
# Out:
# {
#     "account": {
#         "id": 512141,
#         "email_verified": true,
#         "email_verification_required": true,
#         "amazon_account_linked": true
#     },
#     "networks": [
#         {
#             "id": 669977,
#             "created_at": "2024-07-21T12:58:57+00:00",
#             "updated_at": "2024-11-29T22:44:55+00:00",
#             "name": "Home",
#             "time_zone": "Europe/London",
#             "dst": true,
#             "armed": true,
#             "lv_save": true
#         }
#     ],
#     "sync_modules": [
#         {
#             "id": 995766,
#             "created_at": "2024-07-21T14:57:22+00:00",
#             "updated_at": "2024-12-05T03:33:52+00:00",
#             "onboarded": true,
#             "status": "online",
#             "name": "My Blink Sync Module",
#             "serial": "G8T1V80132050EX3",
#             "fw_version": "16.0.20",
#             "type": "sm2",
#             "subtype": "billy",
# ...

# %%
from blinkpy import api


api.request_camera_liveview(blink, 669977, 1121974)
# Out:
# {'command_id': 1776050918,
#  'join_available': True,
#  'join_state': 'available',
#  'server': 'immis://3.74.163.137:443/GlkJbvxsqCfScs-z__IMDS_G8T1GJ0132170WL5?client_id=182',
#  'duration': None,
#  'extended_duration': 5400,
#  'continue_interval': 30,
#  'continue_warning': 10,
#  'polling_interval': 15,
#  'submit_logs': True,
#  'new_command': True,
#  'media_id': None,
#  'options': {}}
